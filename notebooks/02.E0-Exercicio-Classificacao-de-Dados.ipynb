# %%
import zipfile
from io import BytesIO

import numpy as np
import pandas as pd
import requests
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import GridSearchCV, cross_val_score, train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

pd.set_option("display.max_columns", None)

# %% [markdown]
# ## QXD0178 - Mineração de Dados
# # Classificação de dados

# %% [markdown]
# **Professor:** Paulo de Tarso Guerra Oliveira ([paulodetarso@ufc.br](mailto:paulodetarso@ufc.br))

# %% [markdown]
# # Lista de Exercícios: Classificação de dados

# %% [markdown]
# Nesta lista de exercícios, você explorará a aplicação de métodos de aprendizado de máquina para realizar tarefas de classificação de dados. Você usará a base de dados [Food choices: College students' food and cooking preferences](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) e avaliará vários algoritmos de classificação para determinar sua eficácia. O objetivo é entender como diferentes métodos de aprendizado de máquina se comportam em relação à acurácia na classificação de dados.
#
# O exercício será dividido em várias etapas:
#
# 1. **Pré-processamento dos dados:**
#    - Descreva brevemente o conjunto de dados
#    - Limpe o conjunto de dados, tratando valores ausentes, removendo duplicatas e realizando transformações necessárias.
#    - Caso você use os dados pré-processados na lista anterior, faça um breve descritivo dos principais ajustes.
#    - Codifique variáveis categóricas, se necessário, para que possam ser utilizadas em algoritmos de aprendizado de máquina.
#    - Cria a coluna `self_perception_overweight` com valor: `True` se a coluna `self_perception_weight` tem valor 4 ou 5; e `False`, caso contrário.
#    - Remova a coluna `self_perception_weight` do conjunto de dados.
# 2. **Divisão do conjunto de dados:**
#    - Divida o conjunto de dados em um conjunto de treinamento e um conjunto de teste para avaliar o desempenho dos algoritmos.
#    - O mesmo conjunto de teste deve ser usado por todos os algoritmos analizados e nenhum dado deste pode ser usado na fase de treinamento.
#    - O atributo alvo (*rótulo*) da classificação será o campo `self_perception_overweight`.
# 3. **Seleção de algoritmos de classificação:**
#    - Selecione uma variedade de algoritmos de aprendizado de máquina para testar na tarefa de classificação.
#    - Sua seleção deve conter, no mínimo, os seguintes métodos: Naive Bayes, k-Nearest Neighbors, Support Vector Machine (Linear/RBF), Decision Trees, Random Forest, Multilayer Perceptron.
#    - Descreva brevemente como funciona cada algoritmo selecionado.
# 4. **Treinamento e avaliação:**
#    - Treine os algoritmos de classificação usando todo o conjunto de treinamento.
#    - Avalie o desempenho de cada algoritmo no conjunto de teste usando métricas como acurácia, precisão, recall e F1-score.
#    - Repita a análise treinando os algoritmos com validação cruzada.
#    - Repita a análise realizando ajuste de hiperparâmetros.
# 5. **Análise dos resultados:**
#    - Prepare um texto que descreva os resultados obtidos e faça uma análise crítica destes resultados.
#    - Compare o desempenho dos diferentes algoritmos e explique por que alguns apresentaram resultados mais adequados que outros.
#
# Documente todas as etapas em um arquivo Jupyter Notebook (`.ipynb`) que inclua as análises, o código e as justificativas. Lembre-se de que é fundamental justificar todas as decisões tomadas ao longo do processo e documentar as análises de forma clara e concisa. Este trabalho tem como objetivo proporcionar uma compreensão prática da seleção e avaliação de algoritmos de classificação em cenários de aprendizado supervisionado.
#
# Envie seu Jupyter Notebook até a data de entrega especificada nesta tarefa.

# %% [markdown]
# ## Solução

# %% [markdown]
# ### **Coleta da base de dados experimental**

# %%
def extract_database() -> pd.DataFrame:
    try:
        url = "https://www.kaggle.com/api/v1/datasets/download/borapajo/food-choices"
        response = requests.get(url, stream=True)
        response.raise_for_status()
    except requests.HTTPError as exc:
        raise exc

    if response.status_code == 200:
        with zipfile.ZipFile(BytesIO(response.content), "r") as zip_ref:
            # Assuming there's only one file in the zip, we'll read it directly
            # If there are multiple files, adjust the handling accordingly
            with zip_ref.open(zip_ref.namelist()[1]) as file:
                return pd.read_csv(file)
    else:
        raise Exception("Failed to download the file")

# %%
df = extract_database()
df.to_csv("../data/raw/conf_foods.csv", index=False)
df.describe()
# Out:
#            Gender   breakfast  calories_chicken  calories_day  calories_scone  \
# count  125.000000  125.000000        125.000000    106.000000      124.000000
# mean     1.392000    1.112000        577.320000      3.028302      505.241935
# std      0.490161    0.316636        131.214156      0.639308      230.840506
# min      1.000000    1.000000        265.000000      2.000000      315.000000
# 25%      1.000000    1.000000        430.000000      3.000000      420.000000
# 50%      1.000000    1.000000        610.000000      3.000000      420.000000
# 75%      2.000000    1.000000        720.000000      3.000000      420.000000
# max      2.000000    2.000000        720.000000      4.000000      980.000000
#
#           coffee  comfort_food_reasons_coded        cook  \
# count  125.00000                  106.000000  122.000000
# mean     1.75200                    2.698113    2.786885
# std      0.43359                    1.972042    1.038351
# min      1.00000                    1.000000    1.000000
# 25%      2.00000                    2.000000    2.000000
# 50%      2.00000                    2.000000    3.000000
# 75%      2.00000                    3.000000    3.000000
# max      2.00000                    9.000000    5.000000
#
#        comfort_food_reasons_coded.1     cuisine  diet_current_coded  \
# count                    125.000000  108.000000          125.000000
# mean                       2.688000    1.388889            1.760000
# std                        1.910987    0.974759            0.766222
# min                        1.000000    1.000000            1.000000
# 25%                        2.000000    1.000000            1.000000
# 50%                        2.000000    1.000000            2.000000
# 75%                        3.000000    1.000000            2.000000
# max                        9.000000    6.000000            4.000000
#
#             drink  eating_changes_coded  eating_changes_coded1  eating_out  \
# count  123.000000            125.000000             125.000000   125.00000
# mean     1.560976              1.536000               4.552000     2.56000
# std      0.498298              0.757159               2.547788     1.13876
# min      1.000000              1.000000               1.000000     1.00000
# 25%      1.000000              1.000000               3.000000     2.00000
# 50%      2.000000              1.000000               4.000000     2.00000
# 75%      2.000000              2.000000               5.000000     3.00000
# max      2.000000              4.000000              13.000000     5.00000
#
#        employment  ethnic_food    exercise  father_education  \
# count  116.000000   125.000000  112.000000        124.000000
# mean     2.448276     3.744000    1.589286          3.483871
# std      0.533158     1.177093    0.665137          1.206243
# min      1.000000     1.000000    1.000000          1.000000
# 25%      2.000000     3.000000    1.000000          2.000000
# 50%      2.000000     4.000000    1.000000          4.000000
# 75%      3.000000     5.000000    2.000000          4.000000
# max      3.000000     5.000000    3.000000          5.000000
#
#        fav_cuisine_coded    fav_food       fries   fruit_day  grade_level  \
# count         125.000000  123.000000  125.000000  125.000000   125.000000
# mean            2.424000    1.715447    1.088000    4.224000     2.376000
# std             1.947968    0.910056    0.284435    0.923388     1.133536
# min             0.000000    1.000000    1.000000    1.000000     1.000000
# 25%             1.000000    1.000000    1.000000    4.000000     1.000000
# 50%             1.000000    1.000000    1.000000    5.000000     2.000000
# 75%             4.000000    3.000000    1.000000    5.000000     3.000000
# max             8.000000    3.000000    2.000000    5.000000     4.000000
#
#        greek_food  healthy_feeling  ideal_diet_coded      income  indian_food  \
# count  125.000000       125.000000        125.000000  124.000000   125.000000
# mean     3.488000         5.456000          3.704000    4.532258     3.152000
# std      1.365567         2.585643          2.086918    1.456332     1.486802
# min      1.000000         1.000000          1.000000    1.000000     1.000000
# 25%      3.000000         3.000000          2.000000    4.000000     2.000000
# 50%      4.000000         5.000000          3.000000    5.000000     3.000000
# 75%      5.000000         8.000000          6.000000    6.000000     5.000000
# max      5.000000        10.000000          8.000000    6.000000     5.000000
#
#        italian_food  life_rewarding  marital_status  mother_education  \
# count    125.000000      124.000000      124.000000        122.000000
# mean       4.728000        5.104839        1.500000          3.426230
# std        0.587175        3.120399        0.548464          1.170703
# min        3.000000        1.000000        1.000000          1.000000
# 25%        5.000000        2.000000        1.000000          2.000000
# 50%        5.000000        5.000000        1.000000          4.000000
# 75%        5.000000        8.000000        2.000000          4.000000
# max        5.000000       10.000000        4.000000          5.000000
#
#        nutritional_check  on_off_campus  parents_cook  pay_meal_out  \
# count         125.000000     124.000000    125.000000    125.000000
# mean            3.152000       1.322581      1.528000      3.408000
# std             1.205204       0.681323      0.746778      1.040285
# min             1.000000       1.000000      1.000000      2.000000
# 25%             2.000000       1.000000      1.000000      3.000000
# 50%             3.000000       1.000000      1.000000      3.000000
# 75%             4.000000       1.000000      2.000000      4.000000
# max             5.000000       4.000000      5.000000      6.000000
#
#        persian_food  self_perception_weight        soup      sports  \
# count    124.000000              124.000000  124.000000  123.000000
# mean       2.806452                3.120968    1.217742    1.390244
# std        1.423824                1.115980    0.414385    0.489800
# min        1.000000                1.000000    1.000000    1.000000
# 25%        2.000000                2.000000    1.000000    1.000000
# 50%        3.000000                3.000000    1.000000    1.000000
# 75%        4.000000                4.000000    1.000000    2.000000
# max        5.000000                6.000000    2.000000    2.000000
#
#         thai_food  tortilla_calories  turkey_calories  veggies_day  \
# count  125.000000         124.000000       125.000000   125.000000
# mean     3.336000         947.580645       555.040000     4.008000
# std      1.436528         202.090179       152.370379     1.081337
# min      1.000000         580.000000       345.000000     1.000000
# 25%      2.000000         725.000000       500.000000     3.000000
# 50%      3.000000         940.000000       500.000000     4.000000
# 75%      5.000000        1165.000000       690.000000     5.000000
# max      5.000000        1165.000000       850.000000     5.000000
#
#          vitamins  waffle_calories
# count  125.000000       125.000000
# mean     1.512000      1073.400000
# std      0.501867       248.667092
# min      1.000000       575.000000
# 25%      1.000000       900.000000
# 50%      2.000000       900.000000
# 75%      2.000000      1315.000000
# max      2.000000      1315.000000

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  cook  comfort_food_reasons_coded.1  cuisine  \
# 0                         9.0   2.0                             9      NaN
# 1                         1.0   3.0                             1      1.0
# 2                         1.0   1.0                             1      3.0
# 3                         2.0   2.0                             2      2.0
# 4                         1.0   1.0                             1      2.0
#
#                                         diet_current  diet_current_coded  \
# 0                              eat good and exercise                   1
# 1  I eat about three times a day with some snacks...                   2
# 2  toast and fruit for breakfast, salad for lunch...                   3
# 3  College diet, cheap and easy foods most nights...                   2
# 4  I try to eat healthy but often struggle becaus...                   2
#
#    drink                                     eating_changes  \
# 0    1.0                                        eat faster
# 1    2.0                        I eat out more than usual.
# 2    1.0  sometimes choosing to eat fast food instead of...
# 3    2.0     Accepting cheap and premade/store bought foods
# 4    2.0  I have eaten generally the same foods but I do...
#
#    eating_changes_coded  eating_changes_coded1  eating_out  employment  \
# 0                     1                      1           3         3.0
# 1                     1                      2           2         2.0
# 2                     1                      3           2         3.0
# 3                     1                      3           2         3.0
# 4                     3                      4           2         2.0
#
#    ethnic_food  exercise  father_education father_profession     fav_cuisine  \
# 0            1       1.0               5.0         profesor   Arabic cuisine
# 1            4       1.0               2.0    Self employed          Italian
# 2            5       2.0               2.0     owns business         italian
# 3            5       3.0               2.0         Mechanic         Turkish
# 4            4       1.0               4.0                IT        Italian
#
#    fav_cuisine_coded  fav_food                                food_childhood  \
# 0                  3       1.0                            rice  and chicken
# 1                  1       1.0  chicken and biscuits, beef soup, baked beans
# 2                  1       3.0                  mac and cheese, pizza, tacos
# 3                  3       1.0                 Beef stroganoff, tacos, pizza
# 4                  1       3.0                 Pasta, chicken tender, pizza
#
#    fries  fruit_day  grade_level  greek_food  healthy_feeling  \
# 0      2          5            2           5                2
# 1      1          4            4           4                5
# 2      1          5            3           5                6
# 3      2          4            4           5                7
# 4      1          4            4           4                6
#
#                                         healthy_meal  \
# 0                                    looks not oily
# 1  Grains, Veggies, (more of grains and veggies),...
# 2  usually includes natural ingredients; nonproce...
# 3           Fresh fruits& vegetables, organic meats
# 4  A lean protein such as grilled chicken, green ...
#
#                                           ideal_diet  ideal_diet_coded  \
# 0                                     being healthy                  8
# 1  Try to eat 5-6 small meals a day. While trying...                 3
# 2       i would say my ideal diet is my current diet                 6
# 3     Healthy, fresh veggies/fruits & organic foods                  2
# 4  Ideally I would like to be able to eat healthi...                 2
#
#    income  indian_food  italian_food  life_rewarding  marital_status  \
# 0     5.0            5             5             1.0             1.0
# 1     4.0            4             4             1.0             2.0
# 2     6.0            5             5             7.0             2.0
# 3     6.0            5             5             2.0             2.0
# 4     6.0            2             5             1.0             1.0
#
#                                  meals_dinner_friend  mother_education  \
# 0                               rice, chicken,  soup               1.0
# 1                             Pasta, steak, chicken                4.0
# 2  chicken and rice with veggies, pasta, some kin...               2.0
# 3   Grilled chicken \rStuffed Shells\rHomemade Chili               4.0
# 4  Chicken Parmesan, Pulled Pork, Spaghetti and m...               5.0
#
#            mother_profession  nutritional_check  on_off_campus  parents_cook  \
# 0                 unemployed                  5            1.0             1
# 1                  Nurse RN                   4            1.0             1
# 2              owns business                  4            2.0             1
# 3  Special Education Teacher                  2            1.0             1
# 4   Substance Abuse Conselor                  3            1.0             1
#
#    pay_meal_out  persian_food  self_perception_weight  soup  sports  \
# 0             2           5.0                     3.0   1.0     1.0
# 1             4           4.0                     3.0   1.0     1.0
# 2             3           5.0                     6.0   1.0     2.0
# 3             2           5.0                     5.0   1.0     2.0
# 4             4           2.0                     4.0   1.0     1.0
#
#    thai_food  tortilla_calories  turkey_calories  type_sports  veggies_day  \
# 0          1             1165.0              345   car racing            5
# 1          2              725.0              690  Basketball             4
# 2          5             1165.0              500         none            5
# 3          5              725.0              690          NaN            3
# 4          4              940.0              500     Softball            4
#
#    vitamins  waffle_calories                    weight
# 0         1             1315                       187
# 1         2              900                       155
# 2         1              900  I'm not answering this.
# 3         1             1315             Not sure, 240
# 4         2              760                       190

# %% [markdown]
# ### **Pré-processamento dos dados**

# %%
{col: df[col].unique() for col in df.columns}
# Out:
# {'GPA': array(['2.4', '3.654', '3.3', '3.2', '3.5', '2.25', '3.8', '3.904', '3.4',
#         '3.6', '3.1', nan, '4', '2.2', '3.87', '3.7', '3.9', '2.8', '3',
#         '3.65', '3.89', '2.9', '3.605', '3.83', '3.292', '3.35',
#         'Personal ', '2.6', '3.67', '3.73', '3.79 bitch', '2.71', '3.68',
#         '3.75', '3.92', 'Unknown', '3.77', '3.63', '3.882'], dtype=object),
#  'Gender': array([2, 1], dtype=int64),
#  'breakfast': array([1, 2], dtype=int64),
#  'calories_chicken': array([430, 610, 720, 265], dtype=int64),
#  'calories_day': array([nan,  3.,  4.,  2.]),
#  'calories_scone': array([315., 420., 980.,  nan]),
#  'coffee': array([1, 2], dtype=int64),
#  'comfort_food': array(['none', 'chocolate, chips, ice cream',
#         'frozen yogurt, pizza, fast food',
#         'Pizza, Mac and cheese, ice cream', 'Ice cream, chocolate, chips ',
#         'Candy, brownies and soda.',
#         'Chocolate, ice cream, french fries, pretzels',
#         'Ice cream, cheeseburgers, chips.', 'Donuts, ice cream, chips',
#         'Mac and cheese, chocolate, and pasta ',
#         'Pasta, grandma homemade chocolate cake anything homemade ',
#         'chocolate, pasta, soup, chips, popcorn',
#         'Cookies, popcorn, and chips', 'ice cream, cake, chocolate',
#         'Pizza, fruit, spaghetti, chicken and Potatoes  ',
#         'cookies, donuts, candy bars', 'Saltfish, Candy and Kit Kat ',
#         'chips, cookies, ice cream', 'Chocolate, ice crea ',
#         'pizza, wings, Chinese', 'Fast food, pizza, subs',
#         'chocolate, sweets, ice cream', 'burgers, chips, cookies',
#         'Chilli, soup, pot pie', 'Soup, pasta, brownies, cake',
#         'chocolate, ice cream/milkshake, cookies',
#         'Chips, ice cream, microwaveable foods ',
#         'Chicken fingers, pizza ', 'cookies, hot chocolate, beef jerky',
#         'Tomato soup, pizza, Fritos, Meatball sub, Dr. Pepper',
#         'cookies, mac-n-cheese, brownies, french fries, ',
#         'chips and dip, pepsi, ',
#         "Grandma's Chinese, Peruvian food from back home, and sushi",
#         'Ice cream, cookies,  Chinese food, and chicken nuggets ',
#         'french fries, chips, ice cream',
#         'mac n cheese, peanut butter and banana sandwich, omelet',
#         'pizza, doughnuts, mcdonalds ', 'chocolate, chips, candy',
#         'chocolate, popcorn, ice cream',
#         "Candy\rPop\rChocolate \rChipotle \rMoe's ",
#         'Pizza, Ice cream, fries, cereal, cookies  ',
#         'Ice cream, chocolate, twizzlers ',
#         'ice cream, cookie dough, cookies, cheese',
#         'ice cream, cereal, and salt and vinegar chips ',
#         'Potato chips, ice cream, chocolate, cookies',
#         'Mac and cheese, fried chicken, cornbread ',
#         'popcorn, chips, candy, & fries ',
#         'Chex-mix, Wegmans cookies, Cheez-Its ', 'pizza, ice cream, chips',
#         'fried chicken. mashed potatoes, mac and cheese',
#         'Popcorn, Chex Mix, Pizza', 'Burger',
#         'Pizza, chocolate, and ice cream ',
#         'fries, chips, fried chicken, pizza, grapes',
#         'peanut butter sandwich, pretzals, garlic bread',
#         'chips, dip, fries, pizza', 'Pizza, Ice Cream, Chicken Wings',
#         'Pizza chocolate chips bagels ice Capps ',
#         'Chocolate, ice cream, pasta',
#         'Mac n Cheese. Chips and salsa. Ice cream. ',
#         'peanut butter, dessets, pretzels. ',
#         'Macaroons, truffles, peanut butter n chocolate ice cream',
#         'ice cream, cookies, ice cream',
#         'carrots and ranch, pretzels, dark chocolate ',
#         'cookies, nutella, ice cream, coffee, fruit ', 'mac and cheese',
#         'Chocolate, Popcorn, Icecream',
#         'Ice cream, cake, mozzarella sticks, pierogies ',
#         'Chips, Mac and cheese, pizza, French fries ',
#         'Pizza, burritos, slim jims',
#         'Broccoli, spaghetti squash, quinoa, and grilled chicken',
#         'Chocolate, ice cream, cookie dough',
#         'pizza, pretzels, fruit snacks, deli sandwhich',
#         'Chips, ice cream', nan,
#         'mac and cheese, potato soup, ice cream, chips and cheese',
#         'chocolate, pizza, and mashed potatoes', 'Pizza cookies steak ',
#         'chocolate, fruit, and ice cream', 'Chips sweets popcorn',
#         'Cookies, burgers, chicken noodle soup, ice cream',
#         'cake, French fries, chicken nuggets', 'pizza, ice cream, cookies',
#         'Mashed potatoes, pasta', 'Pasta dishes, Cheesecake, Pancakes',
#         'Ice cream, pizza, cookies',
#         'Chinese food, moes, sponge candy, homemade lasagne ',
#         'pizza, pasta, mac and cheese',
#         'Little Debbie snacks, donuts, pizza',
#         'carrots, plantain chips, almonds, popcorn ',
#         'chips, ice cream, fruit snacks',
#         'Macaroni and cheese, chicken noodle soup, pizza',
#         'Chocolate, Chips, Ice cream, French Fires, Pizza',
#         'Mac and cheese, lasagna, Chinese food ',
#         'candy, Chinese, mcdonalds', 'Doritos, mac and cheese, ice cream',
#         'Ice cream, cake, pop, pizza, and milkshakes.',
#         'Mac and Cheese, Pizza, Ice Cream and French Fries ',
#         'Soup, pasta, cake',
#         'mac & cheese, frosted brownies, chicken nuggs',
#         'watermelon, grapes, ice cream',
#         'macaroni and cheese, stuffed peppers, hamburgers, french fries',
#         'Pizza, mashed potatoes, spaghetti',
#         "dark chocolate, terra chips, reese's cups(dark chocolate), and bread/crackers with cottage cheese",
#         'Chips, chocolate, ,mozzarella sticks ', 'ice cream, chips, candy',
#         'Pizza, soda, chocolate brownie, chicken tikka masala and butter naan ',
#         'Chocolate, Pasta, Cookies', 'Candy, salty snacks, toast',
#         'Mac in cheese, pizza, mozzarella sticks ',
#         'Ice-cream, pizza, chocolate', 'snacks, chips, ',
#         'Chocolate, Ice cream, pizza', 'ice cream, pizza, Chinese food ',
#         'Burgers, indian and korean food\r',
#         'chocolate bar, ice cream, pretzels, potato chips and protein bars.',
#         'Ice cream, chocolate, pizza, cucumber ',
#         'Noodle ( any kinds of noodle), Tuna sandwich, and Egg.\r',
#         'Chinese, chips, cake', 'chips, rice, chicken curry,',
#         'wine. mac and cheese, pizza, ice cream ',
#         'Pizza / Wings / Cheesecake', 'rice, potato, seaweed soup',
#         'Mac n Cheese, Lasagna, Pizza', 'Chocolates, pizza, and Ritz.'],
#        dtype=object),
#  'comfort_food_reasons': array(['we dont have comfort ', 'Stress, bored, anger', 'stress, sadness',
#         'Boredom', 'Stress, boredom, cravings ',
#         "None, i don't eat comfort food. I just eat when i'm hungry.",
#         'stress, boredom',
#         'I eat comfort food when im stressed out from school(finals week), when I`m sad, or when i am dealing with personal family issues.',
#         'Boredom ', 'Stress, anger and sadness ',
#         'sadness, stress, cold weather',
#         'Sadness, boredom, late night snack ',
#         'stress,  boredom, special occasions',
#         'Friends, environment and boredom', 'boredom', 'Stress ',
#         "I usually only eat comfort food when I'm bored, if i am doing something, i can go for hours without eating ",
#         'Sadness, stress', 'boredom, sadness, hungry',
#         'happiness, satisfaction', 'Mostly boredom',
#         'sadness, depression ', 'Stress and boredom ',
#         'A long day, not feeling well, winter ', 'Boredom, lazyniss ',
#         'survival, bored', 'Boredom, anger, drunkeness',
#         'stress, boredom, cold weather', 'stres, boredom, and nighttime',
#         'Hunger and Boredom ',
#         'boredom, sadness, and if it has a good taste. ',
#         'boredom, stressed, sad', 'Boredom usually', 'Stress',
#         'boredom, stress', 'No reasons ',
#         "Usually if I'm sad or depressed. ", 'Tired ', 'Boredom!, sadness',
#         'All of the above; sadness, boredom and confusion ',
#         'Stress, boredom, craving', 'Hunger, boredom',
#         'sadness, boredom, & anger ', 'Boredom, happiness, distraught ',
#         'stressed, upset, or just craving a cheat meal',
#         'They taste better than other food. They are a pickme up. They are easy to make',
#         'Stress, boredom', 'Lazy', 'Boredom, sadness and anger ',
#         'Boredom, sadness', 'stress, anger and boredom', 'bored, stress',
#         'I usually only eat comfort foods when I am bored. I will also eat them when I am happy to celebrate and then when I am sad to comfort me.',
#         'Just cause ', 'Stress, boredom, sadness',
#         'Boredom. Celebration. ', 'Sadness, boredom, lonely.',
#         'I do not really eat "comfort food" but I guess sadness, special occasions, and anxiety ',
#         'boredom, sadness', 'sadness', 'Bordem, happiness, sadness',
#         'Stress, sadness, bored ', 'Boredom, stress, and it tastes good',
#         'Bad day, bored, sadness',
#         'Boredom, being in your period, and long bus rides for softball',
#         'boredom, anger, happy', 'Boredom, stress', nan,
#         'sadness, stressed, boredom', 'boredom and stress',
#         'Boredom comfort hunger ', 'happiness, hunger, sadness',
#         'Boredom, sadness, or with friends ',
#         'Sadness, Loneliness, Boredom', 'Mostly Stress',
#         'boredom, sadness ', 'when i am sad or craving',
#         'stress, boredom, college as whole ', 'Boredom and stress',
#         'Stress, sadness, boredom', 'laziness and hungover',
#         'Boredom, hunger, snacking.', 'Happiness, sadness, celebration.',
#         'Boredom, anger and just being hungry in general.',
#         'Depression, comfort, accessibility ',
#         'they are yummy, my boyfriend sometimes makes me sad, boredom',
#         'Sad, bored, excited', 'boredom, stress, mood swings',
#         'Anger, sadness',
#         'Anxiousness, watching TV I desire "comfort food" ',
#         'Boredom, sadness, anxiety', 'Boredom, laziness, anger',
#         'Stress and sadness',
#         'I am always stressed out, and bored when I am in my apartment. ',
#         'Stress, frustration, self-consciousness ', 'Sadness and cravings',
#         'Sadness, happiness and boredom', 'Boredom and sadness',
#         'sadness, happiness and hunger',
#         'Stress, boredom and physical activity',
#         'loneliness, homework, boredom ',
#         "When i'm  eating with my close friends/ Food smell or look good/ when I feel tired",
#         'Happiness, boredom, social event', 'boredom and sadness ',
#         'Loneliness / Homesick / Sadness',
#         'happiness, they are some of my favorite foods',
#         'hormones, Premenstrual syndrome.'], dtype=object),
#  'comfort_food_reasons_coded': array([ 9.,  1.,  2.,  4.,  3.,  7.,  6.,  5.,  8., nan]),
#  'cook': array([ 2.,  3.,  1.,  5.,  4., nan]),
#  'comfort_food_reasons_coded.1': array([9, 1, 2, 4, 3, 7, 6, 5], dtype=int64),
#  'cuisine': array([nan,  1.,  3.,  2.,  6.,  4.,  5.]),
#  'diet_current': array(['eat good and exercise',
#         "I eat about three times a day with some snacks. I try to eat healthy but it doesn't always work out that- sometimes eat fast food and mainly eat at Laker/ Egan ",
#         'toast and fruit for breakfast, salad for lunch, usually grilled chicken and veggies (or some variation) for dinner',
#         'College diet, cheap and easy foods most nights. Weekends traditionally, cook better homemade meals  ',
#         'I try to eat healthy but often struggle because of living on campus. I still try to keep the choices I do make balanced with fruits and vegetables and limit the sweats. ',
#         "My current diet is terrible. I barely have time to eat a meal in a day. When i do eat it's mostly not healthy.",
#         'I eat a lot of chicken and broccoli for dinner, and usually tuna sandwiches for lunch.',
#         'I eat a very healthy diet. Ocassionally, i will eat out and get unhealthy food.',
#         'I eat whatever I want in moderation.',
#         "I eat healthy all the time when possible. I treat myself occasionally. I don't really like the greasy meals, if anything I would eat sweets over the greasy meals.  ",
#         'i eat very healthy. Maybe eat out 1-2 times a week.',
#         'I am very health concious. I eat many fruits, veggies, and protiens. ',
#         'I focus mostly on proteins and fruits. I eat a lot less vegetables and a few carbohydrates.',
#         'Not as healthy when I am at school compared to home. Still very aware of the nutrition I am taking in.',
#         'Making sure I have enough protein intake, as well with fibre, vitamins and carbs. ',
#         'I like a lot of foods that arent home cooked or healthy for you.',
#         'I eat very healthy ',
#         'My current diet is eggs and a meat every morning for breakfast. For lunch ill usually have some pasta or rice with a meat and sometimes a side of veggies. for dinner i usually eat less carbs and more protein and veggies. ',
#         'I eat lots of fruit and veggies. I eat lots of chicken.',
#         "Current diet right now isn't very good. I eat at the school's cafeteria and they do not have the best choices.",
#         'I eat 2 meals a day, lunch and dinner',
#         'Random. Not strict diet, changes during season', 'balanced ',
#         '2 meals a day. Rarely eat snacks. Fairly balanced diet. ',
#         'I eat a lot of chicken and try to cook my own meals as much as possible using a lot of rice and vegetables.',
#         'vegetarian, eat breakfast some days before class, can eat a lot of junk food so I refrain from allowing myself to buy any',
#         "Most healthy diet, but since I'm an athlete have room for some bad foods to burn off quickly ",
#         'Very healthy. Good balance of proteins and vegetables ',
#         'Whats necessary for survival.  ', 'anything and everything',
#         'I eat some vegetables almost everyday and fruit a couple of times a week. I eat meat a few times a week. I dont eat fast food and try to limit fried food.',
#         'Diet consists of 3000-4000 calories a day well rounded from meats, vegetables, and fruit.',
#         'Not that balanced, but I try not to eat fatty or fried foods.',
#         'I eat a a lot of carbs from pizza and pasta. I also eat a lot of cookies. ',
#         'egan dining',
#         'A lot of rice and veggies, eggs for breakfast, chicken is usually the only kind of meat I eat.',
#         "I eat out more often then not. I try to make sure when I eat out it isn't fast food, but instead something healthy like Panera. ",
#         'I do not get to eat as well as I did.  I wish I ate better, but in college it is hard because of money.',
#         'I eat three meals per day usually. I eat a lot of sandwiches and fruit.',
#         'Unhealthy foods from the cafe ',
#         'I will eat a full bleakest every morning consisting of eggs, potatoes, and a type of meat with juice. I will have a sandwich or something light for lunch. For dinner I will have meat and vegetables of some sort.  ',
#         'I eat food ',
#         'Light breakfast, yogurt or grandola bar. No luch but (healthy) snacks throughout this time period until dinner. Full dinner with meat, vegetables and fruit.',
#         'It needs some re-structuring. Mostly, I eat well but I would like to improve on my water, fruit and veggie consumption. ',
#         'I am on a very balanced diet, eating 4-5 small meals a day filled with fruits, vegetables, lean meat, and good carbs. ',
#         'Healthy, includes many fruits and vegetables. Probably too many carbs. ',
#         'At school I eat a lot of pizza or burgers with fries. Occasionally I try to have a salad or a fruit juice with this. I also try to eat more of a home cooked meal with vegetables.',
#         'lots of pasta and carbs along with lean meats. Also at time some soda and junk food',
#         "My current diet consists of cafeteria food, which isn't necessarily ideal. I try to eat as healthy as possible but I find myself turning to unhealthy food more often than healthy.",
#         'I eat alot carbs. Protein (meat) is beautiful.',
#         'Healthier than most but not 100% clean.', 'Great ',
#         'My diet is mostly chicken rice and veggies. I mix in fruit between workouts and snacks like power bars and what not. ',
#         '65 and out',
#         'Very healthy and clean. A lot of protein and vegetables',
#         'What ever the dinning hall is serving. When i am hungry i look for something filling more then healthy. ',
#         'I usually eat very healthy. I incorporate fresh fruits and vegetables into every meal.',
#         'I eat very heathy on a daily basis ',
#         'For breakfast I have oatmeal. For lunch I have a sandwich and fruit. For dinner I usually have a piece of meat, rice or pasta, and a vegetable. ',
#         'Simple breakfast of cereal or yogurt. Lunch is something like a deli meat sandwich. Dinner is a full meal. Veggies meat and starch. ',
#         'My diet consists of fruits, vegetables, grains, dairy, and proteins.',
#         'My diet is pretty healthy and consists of chicken, turcky, and veggies. I rarely eat unhealthy food or fast food.',
#         'I try to eat as healthy as possible. 3 meals a day that are well-balanced.',
#         'High in protein, fruits, and veggies. Low in fats.',
#         'I eat fruit and vetagables with every meal. I only drink water, no soda. I tend to stay away from greasy food. ',
#         "I don't follow a diet, I eat whatever I want",
#         'My current diet usually includes at least one serving of vegetables per day, and I usually am eating fruits and whole grain things. ',
#         'I typically try to eat healthy but being away at school makes it harder. I try to avoid junk food as well and trying to only eat it on the weekends.',
#         'My current diet is balanced and includes food from all the food groups. ',
#         'I am not vegetarian. I love red meat like steak and salami. I try to limit the amount of carbs I eat',
#         'Healthy and light',
#         'My meals consist of a vegetable, a meat and usually a carbohydrate. I eat a lot of fruit and snack in between meals on little things.',
#         'I eat somewhat healthy. The food at egan is not the best.',
#         'I have a diet of meats and other high protein foods. ', nan,
#         'I normally eat a salad every day. I try to get at least every food group into my diet',
#         'Current diet is rather poor.  I eat a lot of chicken and carbs.  I also tend to eat a lot of desserts.',
#         'Meat carbs and candy ',
#         'At school its hard but usually a granola bar and fruit for breakfast, a wrap for dinner or lunch, and then veggies and hummus.',
#         'No diet. I eat what makes me feel good',
#         'If there is berries I will eat them.  Eat any kind of pasta.  Hate cooked vegetables',
#         'I eat fruits, dairy and carbs ',
#         'I eat two-tree meals per day. Always eat a breakfast. ',
#         'I eat healthy as well as unhealthy. I try to keep a balanced diet but often eat junk food with friends.',
#         'I eat a paleo based diet high in protein and low in fat. I stay away from processed foods as much as I can.',
#         "I try to eat something light for breakfast like cereal or an apple. For lunch I eat sandwiches or pasta also something somewhat light and I eat however much I'm hungry for at dinner. Sometimes I try to be healthy with a salad or something and then I get dessert ",
#         'Eat fruits and vegetables daily and with almost every meal. Diet mostly consists of meat as well. ',
#         'I try to eat healthy but sometimes drink soda pop and I enjoy desserts. harder to eat healthy when I am at school. ',
#         'High protein and high carbs with fruits and vegetables as needed',
#         'i currently eat a lot of salad, but do not eat 3 times a day nor eat breakfast ',
#         "I used to eat whatever but since i've come to college i try to eat fruits and vegetables everyday. I also avoid fried foods.",
#         "I eat very basic foods like pizza and pasta. I don't try many new things. ",
#         'My diet consists of high levels of meats with some vegetables. Coexisting with varying levels of sugars ',
#         'Very poor. Heavy carb consumption. ',
#         'Complete diet. protein vegetables and carbs',
#         'I eat usually 2 times a day, either breakfast and dinner or lunch and dinner.  I feel that is enough for me.',
#         'Currently whatever Egan has at the moment.',
#         'I try to maintain a healthy diet. I always try to eat foods that are beneficial to my health and that will impact me in the long run.',
#         'Somewhat unhealthy. This is due to my hectic work and school schedule.',
#         'i drink alot of lemon water, and milk. i also eat ice cream frequently after dinner. but i also eat lots of fruits and veggies',
#         'I typically eat very healthy. i consume fruits and vegetables in about every meal. ',
#         'At this time it is very touch and go. Some days I live on sandwiches and ice cream while other days I eat lots of fruits and vegetables. ',
#         'A very healthy diet. Avoiding junk foods, and any white breads. ',
#         'I have been eating mainly proteins and some fruits and vegetables every day with some less healthy snack foods.  ',
#         'High in carbs, but I have recently tried to cut down on fats, salt, and sugars. I choose more organic options as well as more fruits and vegetables. ',
#         'Since I am a college student I rarely cook full meals with protein, vegetables and starch. I usually just heat up leftovers from a restaurant or go eat casual food at the dining hall.',
#         'It is pretty balanced with a diverse mixture of proteins, carbohydrates, vitamins and minerals. Fruits and chicken dominate my diet. ',
#         'I try to eat a balanced meal. I refrain from anything too fatty. ',
#         'moderately health conscious ',
#         'protein, carbs, less fruits and vegetables, some sweets ',
#         'I eat at least 2 times a day at the universities dining places. I also sometimes cook myself and try to eat healthy a majority of the time. ',
#         'some healthy food and also some not so healthy.',
#         'I eat a lot of proteins and fruit and vegetables. I try to stay away from carbohydrates and sugary foods.',
#         'My current diet would be considered a "college diet". I eat a lot of pizza and ramen noodles. ',
#         'Not very healthy',
#         'I currently eat an abundance of carbohydrates. I have a low intake of protein. I overly intake calcium.',
#         'It is very unbalance. Mostly fat food, Lack of vegetables.',
#         'I eat in dining hall of school everyday. I usually have both meat and a little vegetable in every meal. ',
#         'Try to eat as healthy as possible. A few days where fast food comes into play because of classes. ',
#         'My diet is mostly whatever I get to eat in the grotto commons. Sometimes, I eat outside',
#         'My diet consists mainly of coffee, water, fruits, vegetables, and chicken. I tend to stay away from bread and pasta as much as possible. ',
#         'A college student with an imbalanced diet trying to be healthy.',
#         'Rice, oatmeal, and tea',
#         'I try to eat as healthy as possible everyday.  I have fruit, yogurt and a protein shake everyday.  The other foods i eat vary on a day to day basis.',
#         'high in protein and low in carbohydrates.'], dtype=object),
#  'diet_current_coded': array([1, 2, 3, 4], dtype=int64),
#  'drink': array([ 1.,  2., nan]),
#  'eating_changes': array(['eat faster ', 'I eat out more than usual. ',
#         'sometimes choosing to eat fast food instead of cooking simply for convenience',
#         'Accepting cheap and premade/store bought foods',
#         'I have eaten generally the same foods but I do find myself eating the same food frequently due to what I have found I like from egan and the laker. ',
#         'Eating rice everyday. Eating less homemade food.',
#         "I started eating a lot less and healthier because I wasn't playing sports year round anymore.",
#         'Freshmen year i ate very unhealthy, but now it is much healthier because of self control.',
#         'I snack less',
#         "I cook a lot of my own foods back at home so not being able to cook my own healthy choices. I eat more carbs than normal when I'm at college due to the choices given in the cafe. ",
#         'Nun ', 'Less meat. ',
#         'I have been eating a lot more salads and soups.',
#         'not as healthy because healthy food goes bad quickly and it is expensive',
#         'I knew I would eat alot my freshmen year, before coming to college i had a diet plan. ',
#         'none', 'More Water ',
#         'I would say i just eat a little more, but not in a bad way. I have unlimited swipes at the cafe so instead of snacking on chips before lunch or dinner i will get something from the cafe.',
#         'I ate at the food hall.', 'None really', 'Late night food',
#         'Less money, less food :(', 'got worse ',
#         'Drink coffee all the time. ',
#         'I watch the amount of "snacks" I eat more than I did in high school.',
#         'none, I have dormed since high school',
#         'Tend to eat more fried foods ', 'A lot healthier ',
#         'Too much beef jerky',
#         'Eating less vegetables because they are less available to me. ',
#         'I drink way more coffee and I dont eat at home as often.',
#         'I eat more junk food now.', 'I eat more junk food', 'poor',
#         'My diet is more limited just because of what I have time to make',
#         "I do not snack as often at school. I find that I'm always busy so sometimes I don't have a lot of time to eat. ",
#         'I do not eat as many home cooked meals.',
#         'I have eaten bigger meals.', 'I eat more ',
#         'I eat pretty much the same as I use too. I do have more sweets now though. ',
#         'I do not make my own food very much', 'I do not make my own food',
#         'Now I prepare my own meals, pack my lunch every day and avoid eating out to save money as much as possible.',
#         "I haven't changed much. If anything, I have become more disciplined. ",
#         'I eat smaller portions more often',
#         'Eating more pizza and burgers or fast food.  ',
#         'Cereal became an anytime of day food',
#         'Transitioning from home-cooked meals to cafeteria food',
#         'I definitely eat less veggies. ',
#         'I have started eating a lot healthier.', 'Mediocre ',
#         'I eat very bad on the weekends. ', nan,
#         'I eat a lot more healthier',
#         'when i eat has changed alot. I have to eat at a certain time everyday or the dining hall wont have food.',
#         'I have begun to eat more fruits and vegetables because I have been more aware of my physique.',
#         'Really paid more attention to what I eat cause it is easy to gain ',
#         'More easy meals like pasta.', 'More snacking ',
#         "At first I ate less but now that I'm in season playing a sport I eat more.",
#         'I have gotten healthier with my eating habits. As a result my parents starting eating healthier too, even though I do not live with them.',
#         'As an athlete it is important to fuel my body with important foods only.',
#         'I ate more junk food, but also more fruit. ',
#         'I snack more, having fewer full meals',
#         'I eat more fried food, such as french fries.',
#         'I eat a lot less than I did at home but find myself snacking more than actual meals. ',
#         "I don't eat as healthy because there aren't as many healthy options at the dinning hall. ",
#         'Freshman year I did not watch my diet at all and really let myself go. I ate pizza and fries for almost every meal. Summer following freshman year I knew I needed to stop doing that so I cut out as many refined carbs as I could and try to eat healthier portions.',
#         "I don't eat as often",
#         'I tend to snack more and have smaller meals.',
#         'I eat a lot less and more junk food.',
#         'I stopped drinking soda and only drink water now',
#         'I do not eat as many fruits and vegetables as I normally would as being home even though i do eat them still',
#         'I eat less healthy breakfast now, usually just grab something quick like a granola bar.',
#         'Expansion of eating variety ',
#         'not going to Egan every meal maybe once a day',
#         'More coffee less water ', 'Less fruits and veggies',
#         'convenience food ', 'Food is not as healthy. ',
#         'Eating at Egan or the laker has definitely made me gain weight because every time I go home and eat I lose weight. ',
#         'Huge changes have occurred. I eat far healthier, less processed  food, less dense carbohydrates and way more vegetables and fruits.',
#         'I eat way too often and way too much x', 'Less snacking ',
#         'less healthy because of less options, money and time.',
#         'Willingly eating vegetables ',
#         'I have been eating healthier especially vegetables and proteinous food ',
#         'i eat healthier all around',
#         "Home cooked meals and a lot more difficult to have at college. It's typically quick, on the go foods. ",
#         'I have increased the amounts of vegetables I eat due to the unhealthy options in our dining halls',
#         'I eat alot of carbs and eat much more frequently',
#         'I eat whatever is offered at egan or at the laker',
#         "Food is readily available so I don't have to cook so it's easier to eat a lot.",
#         "I've eaten more fruits and vegetables. Started eating seafood.",
#         'Coming to college I definitely have tried to change my eating habits in order to maintain my weight and be more healthy. ',
#         'When I was on campus (which I am not anymore) I ate way more fruits and vegetables since I had easy access to them.',
#         'eat more salads',
#         "I consume a lot more grapefuit since I've come to college. The meals here are also more greasy than I am used to. ",
#         'I eat a lot more carbs than I did when I lived at home.',
#         'Avoiding "easy options" such as junk foods ',
#         'Coming to college I have ate less well colored meals each day due to lack of income and desire to save money. I used to eat more fruits and vegetables, more chicken and salmon, now these habits have lightened up and are not as frequent and regular in the week. I have also started eating more bread and dairy products.',
#         "I've definitely gotten used to eating more often since I have a fully cooked meal available to me at all the time.  Sometimes I would only eat one full meal and a snack in high school because I was so busy and did not have the time to cook. ",
#         'I do not eat full meals. Rarely eat 3 meals a day. ',
#         "I have been drinking more water. Since college, I've been more conscious about my diet and incorporated more fruits on my diet. ",
#         'My diet could improve now. I have been eating more than I should.',
#         'Late night snacking', 'I snack less and eat smaller portions ',
#         'I eat out more. ', 'more healthy food',
#         'I had to change a lot. I keep track of calories and cut out most breads and wraps.',
#         'They have gotten very bad. I eat a lot more food that I know I should not eat. ',
#         'not eating meals on time',
#         'Eating more dairy due to more ice cream intake.',
#         'less vegetable more sweats',
#         'I eat more vegetable. Since coming to college, I started to eat salads and tried to eat salads at least three times a week.',
#         'I try to eat more fruits and vegetables ',
#         'Started eating a lot of protein rich food that i didnt before.',
#         'I have noticed there is less time for a prepared meal, so quick and easy has become the norm.',
#         'Eating Pizza as an excuse when there is nothing else to it.',
#         'less rice',
#         "I don't eat as much on a daily basis since coming to college.",
#         'I have learned to eat more vegetables. '], dtype=object),
#  'eating_changes_coded': array([1, 3, 2, 4], dtype=int64),
#  'eating_changes_coded1': array([ 1,  2,  3,  4,  5,  8,  6,  7,  9, 10, 11, 12, 13], dtype=int64),
#  'eating_out': array([3, 2, 1, 5, 4], dtype=int64),
#  'employment': array([ 3.,  2.,  1., nan]),
#  'ethnic_food': array([1, 4, 5, 2, 3], dtype=int64),
#  'exercise': array([ 1.,  2.,  3., nan]),
#  'father_education': array([ 5.,  2.,  4.,  1.,  3., nan]),
#  'father_profession': array(['profesor ', 'Self employed ', 'owns business', 'Mechanic ', 'IT',
#         'Taxi Driver', 'Assembler ', 'Business guy',
#         'High School Principal', 'commissioner of erie county ', 'Idk',
#         'Home Marker ', 'Shirt designer ', 'business owner',
#         'Commidity trader ', 'Hockey Coach', 'Construction ',
#         'self employed construction ', 'Engineer', 'architect', 'CFO',
#         'European logistics director ', 'accountant ',
#         'Commercial Real Estate', 'Manager at Pepsi', 'VP of ',
#         'Beverage and Food Sales', 'Dentist ', 'Electrical Engineer',
#         'Radio Telecommunications Manager', nan, 'deceased', 'Lawyer',
#         'landscaping ', 'Vice President of a company',
#         'Owns his own promotional company ', 'Optometrist ',
#         'Biohemical Waste Elimination', 'Corporate Manager ',
#         'Small business owner ', 'Welder', 'Design Engineer', 'Unknown ',
#         'Banker', 'subcontractor ', 'small business owner ',
#         'House Appraiser', 'not sure', 'Fireman',
#         'President of Automotive company ', 'UPS driver ',
#         'HVAC Professional', 'Sergeant correctional officer',
#         'union worker', 'Salesman', 'Owns his business',
#         'Physical Therapist', 'Insurance ', 'Construction management ',
#         'Dead beat ', 'police force', 'VP of GNC',
#         'Owner of New York Lunch', 'Dentist', 'mechanic ', 'Truck Driver ',
#         'Sales Manager ', 'Retired - Bus Driver', 'Transportation ',
#         'Police Officer', 'Risk Manager', 'retire', 'car salesman',
#         'dairy farmer', 'Dairy Farmer ', 'self employed',
#         'Contract negotiations', 'Police Officer ',
#         'Works for Kirila Fire', 'Realtor', 'Solar Engineering ',
#         'Service Technition', 'engineer ', 'handyman', 'cross-guard ',
#         'Project manager', 'Teacher', 'Truck Driver', 'Senior Manager',
#         'information systems architect', 'Supervisor',
#         'Delivery Man For Fritolay', 'Business Owner', 'Beacon Light ',
#         'salesman', 'Mechanical Engineer', 'GE Salesman',
#         'Ford Plant employee', 'Clinical Researcher', 'Retired ', 'Sales',
#         'School Library Media Specialist ', 'Retired',
#         'Mechanical Engineer ', 'Politician', 'Pharmaceutical',
#         'Business Man', 'His own business', 'HVAC technician ',
#         'United Nations', 'Accountant ', 'Doctor', 'CEO of company',
#         'Store manager at Giant Eagle', 'Journalist'], dtype=object),
#  'fav_cuisine': array(['Arabic cuisine', 'Italian', 'italian', 'Turkish ', 'Italian ',
#         'African', 'Thai', 'Anything american style.', 'Seafood',
#         'Orange chicken and chow mani noodles ', 'Chinese ',
#         'italian food', 'Jamaican ', 'American or Italian ', 'Chicken ',
#         'Mexican', 'Indian', 'italian ', 'Asian ', 'Chinese',
#         "don't have one", 'Italian food ', 'Mexican ', 'Italian/German',
#         'Indian food - samosas are amazing', 'mexican', 'Spanish',
#         'French', 'American or Italian', 'Italian or Chinese ', 'chinese',
#         'Thai food', 'Greek', 'American', 'All ', 'Sub sandwhiches',
#         'Wraps ', "Chinese cuisine (General Tso's)", 'American ', 'Lean',
#         nan, 'american ', 'Japanese', 'Any type of Colombian cuisine',
#         'Mexican cuisine', 'Asian', 'Chinese food', 'mac and cheese',
#         'Authentic Chinese and Vietnamese food ', 'italian and chinese',
#         'Barbecue ', 'lebanese or greek', 'sushi', 'Indian food', 'Nepali',
#         'I really love italian food and thai food', 'Korean',
#         'I do not like cuisine', 'Vietnamese cuisine', 'Mexican Food',
#         'HISPANIC CUISINE.'], dtype=object),
#  'fav_cuisine_coded': array([3, 1, 6, 4, 5, 7, 2, 8, 0], dtype=int64),
#  'fav_food': array([ 1.,  3.,  2., nan]),
#  'food_childhood': array(['rice  and chicken ',
#         'chicken and biscuits, beef soup, baked beans',
#         'mac and cheese, pizza, tacos', 'Beef stroganoff, tacos, pizza',
#         'Pasta, chicken tender, pizza ', 'Fries, plaintain & fried fish',
#         'grilled chicken, hamburgers',
#         'chicken, cheesey potatoes, and hot dogs', 'Shrimp, spaghetti',
#         'Pasta, Eggs, Pancakes ', 'Chicken', 'Scalloped potatoes and ham ',
#         'Pizza, chicken wings, and corn on the cob ',
#         'steak, lasagna, crab', 'Pizza', 'pizza',
#         'Curry, Stew Chicken and Saltfish',
#         'chicken fingers, steak, mac and cheese', 'manacotti',
#         'pizza, chicken fingers', 'Pasta', 'pasta', 'Chicken Nuggets',
#         'Spaghetti ', 'Chicken parm, beef stroganof, tacos',
#         'Chicken Parm, Pizza ', 'Steak',
#         'Deer Steak, Buttered Pasta, Garlic Pasta',
#         'Crab legs, Mushroom soup, homemade rolls',
#         'french fries, waffles, chocolate', 'chicken and biscuits',
#         'Spaghetti, Chicken, Won Tons',
#         'Chicken Nuggets, Mac and Cheese, and pasta',
#         'hamburgers, chicken nuggets ', 'chicken, pasta, stir fry',
#         'pizza, pasta, grilled cheese ', 'chicken parmesan',
#         'Chicken and steak ', 'pizza, ice cream. pop tarts ',
#         'Mac cheese ', 'French Toast, Grilled Cheese, Orange Chicken',
#         'pickles, chinese food, pizza',
#         'Mac and Cheese, Hot Dogs, Grilled Cheese',
#         'Hamloaf, tuna fish salad, mac and cheese ',
#         'chicken soup,  perogies, & roast beef  ',
#         'lasagna, meatloaf, pizza', 'Tacos, Spaghetti, and Roast',
#         'mac and cheease, mashed potatoes, salmon', 'Steak ',
#         'Grilled chicken, pasta, and turkey ',
#         'Chicken, Pizza, Cherry tomatoes', 'Chicken Alfredo',
#         'steak and cheesy potatoes', 'Meatloaf',
#         'Pizza pasta and quesadillas ', 'Mac and cheese ', 'lasagna',
#         'Chocolate', 'Pizza, Pasta, Chicken',
#         'chicken tenders, pasta, mac&cheese ',
#         'chicken stir fry, spaghetti, chicken parmesan ',
#         'Mac and Cheese, Chicken nuggets', 'Mac&Cheese, Chicken Nuggets ',
#         'Pasta, pizza, meatballs ',
#         'Steak, Garlic and butter noodles, schnitzle',
#         'Pizza and Spaghetti', 'Pizza Mac n Cheese Pasta', nan,
#         'salad, chicken, pizza',
#         'pizza, mashed potatoes, chocolate chip cookies',
#         'Pizza and wings ', 'tacos, pizza, chicken wing dip',
#         'Sloppy joes', 'Spaghetti and Meatballs, Steak, and Burgers',
#         'chicken fingers, pasta, pizza', 'spaghetti and tacos',
#         'Spaghetti or  chicken panini sandwich ',
#         'Spaghetti and Pop-tarts', 'Pasta, breakfast for dinner, pizza',
#         'peanut butter and jelly, celery and peanut butter, hot pockets ',
#         'Quesadilla, chocolate, steak', 'Jollof Rice, Bread, pasta ',
#         'Chinese food, pizza, chicken adobo', 'Pasta, chicken, pizza ',
#         'Steak, Chicken Tenders, Pizza', 'Spaghetti, Italian potato soup',
#         'steak, spaghetti, salmon', 'Macaroni and Cheese',
#         'Chicken Parm, Spaghetti, and Grilled Cheese',
#         'Chicken parmigiana, wedding soup, pasta',
#         'chicken, macaroni & cheese, cheesy potatoes',
#         'Spaghetti, Tuna noodle casserole, Italian sausage',
#         'chicken nuggets, macaroni and cheese',
#         'Tortellini and Broccoli with parmesan cheese and homemade breaded chicken with sweet potato',
#         'Chicken Marsala, Manicotti, Mashed Potatoes',
#         'hot dogs, chicken fingers, mashed potatoes',
#         "Chicken Biryani, Dad's burgers, Chicken curry",
#         'dino chicken nuggets', 'Spaghetti and chicken parm',
#         'Chicken parm. ', 'Spaghetti', 'Pizza, Pita, Lasagna',
#         'Mac & Cheese, Chicken, Stir Fry ', 'Mac and Cheese ',
#         'Dumplings, Chicken Curry and Pizza', 'Pasta, Pizza, Popcorn',
#         'Fry Chicken, Rice Vegetable', 'Noodle, Wings, and Tiramisu',
#         'Chinese', 'pizza, burger, pasta',
#         'Stromboli Mac and Cheese and Pizza',
#         'Isombe , Plantains and Ugali', 'Rice and potato',
#         'pizza and spaghetti ',
#         'rice, beans, and chicken / pizza/ tenders'], dtype=object),
#  'fries': array([2, 1], dtype=int64),
#  'fruit_day': array([5, 4, 2, 3, 1], dtype=int64),
#  'grade_level': array([2, 4, 3, 1], dtype=int64),
#  'greek_food': array([5, 4, 2, 3, 1], dtype=int64),
#  'healthy_feeling': array([ 2,  5,  6,  7,  4,  3,  9,  1,  8, 10], dtype=int64),
#  'healthy_meal': array(['looks not oily ',
#         'Grains, Veggies, (more of grains and veggies), small protein and fruit with dairy ',
#         'usually includes natural ingredients; nonprocessed food',
#         'Fresh fruits& vegetables, organic meats ',
#         'A lean protein such as grilled chicken, green vegetables and  brown rice or other whole grain ',
#         'Requires veggies, fruits and a cooked meal. ',
#         'Protein, vegetables, fruit, and some carbs',
#         'A healthy meal has a piece of meat followed by a lot of fruit and veggies',
#         'Colorful', 'Chicken and rice with a side of veggies. ',
#         'Chicken, and veggies ',
#         'lean protein, veggies, fruit, complex carbs',
#         'A salad with a reasonable amount of dressing and a meat.',
#         'Lots of vegetabls with some grains like rice. Also has lean meat such as fish or chicken.',
#         'Green and not greasy', 'chicken, veggies, rice',
#         'Not too much carbs, a lot of protein, healthy fats and fruits and vegs ',
#         'for me usually a big piece of chicken or steak with a side of veggies, and i usually have rice with mine as well',
#         'Everything from food group ',
#         'lots of fruits and vegitibles, not any fried foods',
#         'Rice, Meat, vegetable', 'Green and colourful',
#         'pasta. veg, water ', 'Protein, vegetables, grains ',
#         'A healthy meal is a lean meat with mostly vegetables and a starch like brown rice or quinoa.',
#         'good portions, lots of color, targets main food groups',
#         'A rice, a vegetable, a piece of meat ',
#         'Salad, vegetable, carb, protein ',
#         'Protein, vegetable and grains',
#         'Grilled chicken, mac and cheese, broccoli, apple, milk',
#         'whole grain carbs, vegetables, a small amount of protein',
#         '4-6 ounces chicken or fish, side of potatoes, and green beans',
#         'Plenty of greens and lean proteins',
#         'A balance of vegetables and cooked lean meat.', 'a lot of greens',
#         'Some kind of protein, a vegetable, and a grain',
#         'a meal with a meat, vegetable, grain, and fruit ',
#         'A protein, starch, veg, and a healthier dessert. ',
#         'a lean protein plus the addition of 2-3 fruits and vegetables',
#         'Chicken breast with veggies ',
#         'A meal with all of the food groups. ',
#         'a salad with chicken and 2 tablespoons of salad dressing ',
#         'Grilled chicken, side salad, rice and broccoli and cranberries',
#         'It is probably more on the green side and there is less fryed or overly seasoned food. There would be more organic foods rather than processed foods. ',
#         'Mostly green!', 'Colorful ',
#         'A meal that you have cooked yourself without a lot of grease or fat in it.  ',
#         'good balance between meats, grains, fruits, vegetables, carbs, and dairy products ',
#         'one that is well balanced and consists on main food groups',
#         'lots of green and color.',
#         'Balance of veggies, white meat, fruits, and grains.', 'Chicken ',
#         'Low carbs and high protein ',
#         'Grilled, natural ingredients, and no carbonated beverages',
#         'High protein and vegetables',
#         'the different colors of the rain bow. protein, fruit, veggies',
#         'Low protein and carbs and high in vegetables and fruits.',
#         'Chicken and broccoli ', 'Fruit, vegetables, and protien',
#         'Proper serving sizes of almost anything ',
#         'Half the plate fruit and vegetables. Other half grains and protein. Then a little dairy. ',
#         'chicken, veggies, fruit, water ',
#         'high protein, low fat, low carbs and sugar',
#         'high protein, fruit, veggies, low carbs and fat',
#         "Meal prep'd foods with food from each section on the food pyramid. ",
#         'vegtables',
#         'Milk for a drink, meat, a grain, vegetable, fruit for dinner',
#         'It has protein, vegetables and some carbs ',
#         'Balanced between protein, veggies, and carbs',
#         'Well portioned meat, veggies, and fruits. Water instead of a sugary drink like pop. ',
#         'A vegetable, a protein, and a fruit',
#         'A balanced meal with a protein, carbohydrate and a vegetable.',
#         'salad', 'Protein source, vegetables, fruits, whole grains', nan,
#         'grilled meat, fruit, vegetable, and some grains',
#         'a plate that has a variety of colors not just one color',
#         'Meat and potatoes ',
#         'good portions of fruit, protein, veggies and carbs',
#         'All food groups',
#         'All of the food groups(carbs, veggies, fruits,etc)',
#         'all elements of food pyramid', 'lots of colors',
#         'Has fruits vegetables and or some type of meat ',
#         'Mostly vegetables and plenty of lean protein and healthy fats to keep you full',
#         'Lots of Greens, meat and water',
#         'Small portion of meat with majority fruits or vegetables ',
#         'lots of variety and veggies',
#         'High protein, high carbs , vegetables ',
#         'Healthy meal for me is a food rich in protein, fiber, some sort of carbohydrates',
#         'half a plate of protein, quarter of a plate of carbs and the other quarter fruits or veggies.',
#         'Very colorful and smaller portions of the unhealthy food with larger portions of vegetables ',
#         'Chicken Salad with Pita Chips', 'Fruits, vegetables, meat ',
#         'steak or salmon with broccoli or asparagus and brown rice or quinoa',
#         'a balance of Meat and vegetables',
#         'Modest proportions of many different food groups.',
#         'It combines a protein with other elements of the diet such as vegetables and other items that support the body.',
#         'Well balanced with protein, fruits, vegetables, starch, etc.',
#         'lean meat, fresh fruits & veggies',
#         'water, fruits, vegetables, protein, carbs',
#         'More vegetables and fruits as opposed to meat and bread/potatoes',
#         'A protein, veggies, and a carb',
#         'Salmon, sweet potato, and larger portion, but equally spread of broccoli, squash, zucchini, carrots, and tomatoes.',
#         'Vegetables, white meat, and a starch like potatoes, water, and fruit for dessert ',
#         'I think a healthy meals includes some kind of protein, preferably meat, vegetables, and a starch such as potatoes or rice',
#         'A healthy meal constitutes of balanced diet with fruits and veggies dominating the plate. ',
#         'To me a healthy meal is balanced and ',
#         'equal portions of carbs, proteins and fruits/veges',
#         'Salad with chicken and vegetables with a raspberry vinaigrette ',
#         'It includes a protein, vegetable, fruit, and grain. ',
#         'low calories plenty of veggies',
#         'A pice of meat such as chicken with a side of vegetables and possibly a salad',
#         'Blackened Chicken, broccoli, and milk',
#         'Meat, greens and food containing protein',
#         'Intaking the proper amount of each food group',
#         'BBQ Chicken with mash sweat potatoes and steam vegetable with corn and a glass of water.',
#         'Including both vegetable and meat',
#         'Chicken vegetables and fruit for dinner ',
#         'A diet that is well balanced in most of the nutrients needed for the body.',
#         'mainly protein and vegetables with a complex carb ',
#         'A healthy meal is a variety of food , organic food that gives you the nutrients such as protein , carbohydrates , fat , water , vitamins and minerals.',
#         'lots of vegetables',
#         'A protein, a fruit, a starch, and a salad or some sort of vegetable.',
#         'a cup of rice, vegetables, and meat. '], dtype=object),
#  'ideal_diet': array(['being healthy ',
# ...
#         'Healthy and light',
#         'I would like to eat less carbohydrates, such as pasta and breads. I wish I knew how to incorporate healthier alternatives to the foods I eat.',
#         'I would like to consume a lot more meat and protein. I want to consume more fruit.',
#         'A balanced diet with each food group. Getting enough protein and carbohydrates.',
#         nan,
#         'Eating all fruits and vegetables. Staying away from all the unhealthy foods.',
#         'My idea diet would consist of eating more balanced diet consisting of fruits, vegetables, and meat.  I would like to not eat so much unhealthy junk food/desserts.',
#         'Meat carbs and candy ',
#         'To eat moderations of every food group each day and no processed food',
#         'Whatever makes me feel good. Doesnt cost a fortune. ',
#         'More fruits and Veggies.  Less carbs', 'a colorful diet',
#         'A good breakfast. A healthy lunch and dinner.',
#         'Delicious but also very healthy for you. Low in carbs but does not delete carbs all together.',
#         'Staying away from processed foods completely and incorporating more plant proteins opposed to meat proteins would be ideals.',
#         'Healthy smoothies for breakfast, healthy sandwich for lunch. For dinner, something wholesome and also healthy. Then a light dessert.',
#         'More organic food. Want to try and add more seafood into my diet.  ',
#         'Eating healthy with lots of water and natural foods. ',
#         'Same as current diet ',
#         'it would be a vegetarian diet without any red meat ',
#         'My ideal diet would be no processed food or fried food. Also, very low in excess carbs and high in protein.',
#         'Ideally I would eat more fruits and vegetables in my diet along with some junk food. ',
#         'A balance between meats and vegetables with less sugar',
#         'Alot of fruits and veggies. Meat and bread. Water, because hydration is important kids',
#         'High protein with lots of vegetables and fruit',
#         'I like the diet I have now.  I could eat 3 times a day but I feel healthy as is.',
#         'Variety of fruits, vegetables, and meats in healthy proportion.',
#         'I want to aim to eat foods that are healthy and nutritious. Since I workout a lot, I want to eat foods that will replenish the nutrients my body needs in order to function. ',
#         'My ideal diet would be one that is well balanced. It would include lots of fruits and vegetables.',
#         'ideal diet would be less sweets and carbohydrates. ',
#         "Although I don't eat junk food very often, i would love not to have those days where I eat a lot. ",
#         'If at all possible, I would like to be able to eat a lot healthier. I would like to eat more fruits and vegetables with the hope of eventually going vegetarian.',
#         'A very healthy diet, with the occasional splurging on junk foods. ',
#         'I would like my diet to fulfill all the colors of the rainbow, with mainly fruits and vegetables as the primary source of intake, and about one fourth intake of proteins, and little to no snacks per day.  ',
#         'A low car, low fat diet with no red meat and lots of plant-based things. I would like to cut red meat out entirely and also cut down on processed snack foods. ',
#         'My ideal diet right now would be how it was when I lived at home. I ate breakfast every morning, brought a lunch to school, and had a home cooked meal by my mom that included meat, vegetables and a starch. ',
#         'My ideal diet would getting to eat small portioned meals in every 2-3 hours. ',
#         'I would like to try to eat vegan. ',
#         'Small portions, healthy foods',
#         'Much more vegetables and lean protein',
#         'I hope to continue to eat healthy and cook more on my own. I want to incorporate more fruits and vegetables. ',
#         'more healthy food such as vegetables than bad food such as burgers.',
#         "I wouldn't want or crave any sweets or breads.I would be satisfied with protein and fruit and veggies. ",
#         'My ideal diet would be a healthy diet. I would eat meats and veggies. ',
#         'Healthy and tasty',
#         'My ideal diet would be an equal balance of all the food groups. I would like to eat more protein. Also, i would prefer to cut back on the junk food.',
#         'Very healthy. Freshly done. properly cooked',
#         'My ideal diet should include both vegetable and meat. It is not only healthy but also delicious. ',
#         'All home cooked. Healthy. Vegetables and fruit. ',
#         'Healthy balanced diet that tastes well.',
#         'My ideal diet would consist of a majority of what I consume now. I like to think I make pretty healthy choices currently, so it would most likely remain the same.',
#         'Eating home cooked meals everyday and being able to not eat processed foods at all.',
#         'lots of veggies',
#         'My ideal diet is the diet i am currently on.  The only thing i would change is a little bit less snack/junk food.',
#         'Being able to balance between sweets, vegetables, fruits, carbohydrates, and fat.'],
#        dtype=object),
#  'ideal_diet_coded': array([8, 3, 6, 2, 7, 1, 5, 4], dtype=int64),
#  'income': array([ 5.,  4.,  6.,  1.,  3.,  2., nan]),
#  'indian_food': array([5, 4, 2, 1, 3], dtype=int64),
#  'italian_food': array([5, 4, 3], dtype=int64),
#  'life_rewarding': array([ 1.,  7.,  2.,  4.,  8.,  3.,  9., 10., nan,  5.,  6.]),
#  'marital_status': array([ 1.,  2.,  4., nan]),
#  'meals_dinner_friend': array(['rice, chicken,  soup', 'Pasta, steak, chicken ',
#         'chicken and rice with veggies, pasta, some kind of healthy recipe',
#         'Grilled chicken \rStuffed Shells\rHomemade Chili',
#         'Chicken Parmesan, Pulled Pork, Spaghetti and meatballs ',
#         "Anything they'd want. I'd ask them before hand what they want to eat and it depends on which type of friend is coming.",
#         'Grilled chicken, steak, pizza', 'chicken, steak, pasta ',
#         'Pasta, Fish, Steak', 'pasta salad and bread',
#         'chicken al king, spaghetti, fish',
#         'Chicken parm, Fish, Pasta dishes ', 'Cereal, pizza, toast ',
#         'pasta, chicken, steak', 'Pizza, chicken and rice, roast beef.',
#         'pizza buffalo chicken pasta',
#         'Curry goat, saltfish, jerk chicken ',
#         'Grilled chicken or steak with veggies and rice. or some type of pasta and chicken ',
#         'Spaghetti, Chicken, Steak', 'chicken, manicotti, rice',
#         'Chicken, Pasta, Veal', 'Meat, wine, chocolate pudding',
#         'pasta, pizza ', 'Pizza, Pasta, Poutine',
#         'Pasta, chicken and rice, and soup', 'Pasta\rTake out',
#         'Chicken parm ', 'Steak, lobster, chicken ',
#         'Garlic noodles and steak, Parmesan chicken and pasta, Tacos and pasta',
#         'Tomato soup, Steak, crab', 'pasta, chicken with potatoes, pizza ',
#         'Chicken, Steak, Pasta', 'Pasta,Sushi,Steak',
#         'Chicken Parmesan, pasta,  ', 'pasta, lasagna, chicken ',
#         'Some kind of pasta, a chicken dish, some kind of salad',
#         'spaghetti or pasta, shrimp fried rice, chicken ',
#         'Pasta, Pizza, Chicken ',
#         'Chicken Parmesan, Orange Chicken, Tacos',
#         'Steak and potatoes, burgers and fries, bacon and eggs ',
#         'Pizza, Japanize Hibachi, Moes   ', 'Chicken, Pasta, Salad',
#         'Pancakes, Pasta, Grilled Cheese and Soup', 'pasta, soup, steak  ',
#         'Steak, asparagus and potatoes, homemade chicken alfredo, Mexican cuisine',
#         'Tacos, spaghetti, grilled cheese', 'Spaghetti, steak, burgers ',
#         'lasagna,  hamburgers w/ corn, steak  ', 'Steak, Chicken, Tacos',
#         'pizza, pasta, burgers', 'Pizza, salad', 'Steak, Chicken, Pasta ',
#         'Chicken Parm', 'Pizza, Steak, Spaghetti',
#         'mac n cheese, steak, potatos', 'Chicken, Beef, Steak',
#         'chicken, pizza, stuffed shells', 'steak, noodles, edemame',
#         'Steak and veggies. Chicken and rice. Stirfry. ',
#         'Lasagna, steak, chili ', 'I would say "lets go out"',
#         'pasta, chicken, vegetables',
#         'chicken and pasta, homemade pizza, lasagna ',
#         '1. pasta 2. spaghetti 3. chicken and rice ',
#         'Lasagna, Steak, Pasta ', 'mac and cheese, pizza, chicken ',
#         'Lasagna, Pizza, Pasta ', 'pasta, chicken parm, tacos ',
#         'Steak, pasta, burgers',
#         'Pizza, Italian, anything chicken related',
#         'Spaghetti, steak, or chicken', 'Pasta, Steak, Chicken',
#         'chipotle, chick fil a, chicken and rice',
#         'rice and Chicken, sea food', 'Chicken, Spaghetti, Hamburgers',
#         'chicken, steak, pizza', 'Steak, Pizza, Haddock ',
#         'mexican chicken, hibachi chicken and rice, steak',
#         'Chicken and vegetables, Roast Beef, pasta',
#         'Salad, pasta, and ice cream',
#         'steak, mashed potatoes, vegetables ', 'pizza, tacos, pasta',
#         'Spaghetti con Chorizo, Carne Asada, Salmon',
#         'Stuffed chicken breasts, spagetti carbonara, breakfast for dinner ',
#         'Pasta, breakfast for dinner, pizza',
#         'Pizza, Chicken and rice and pasta', 'Pasta, pizza, and chicken',
#         'burritos, pasta, chicken',
#         'Rice with vegetables, chicken with pasta, salad',
#         'any Chinese food, pasta, burgers', 'Pasta, chicken, pizza ',
#         'Chicken, Pork Chops, Steak',
#         'Salmon, hamburger surprise, Italian potato soup',
#         'salmon, steak, spaghetti squash', 'Pasta, fish, steak',
#         'Pizza, chicken, pasta',
#         'Chicken Parm, Baked Ziti, Shrimp Alfredo ',
#         'Chicken parmigiana, pasta, wedding soup',
#         'chicken alfredo, chicken parmesan, spaghetti',
#         'spaghetti, steak, lasagna ', nan,
#         'Spaghetti and pasta, seasoned salmon with steamed or boiled broccoli, or soup with ritz crackers if I was busy that day.',
#         'Pasta, Burgers and Fries, Chicken Marsala',
#         'Chicken rice and asparagus, pizza, something easy in the crockpot',
#         'Marinated nuts, prawn crackers, drink of their choice, mixed veggie crackers\rRice, chicken curry, lentil, pickle, potato kebab\rLemon Meringue Pie',
#         'Pasta, Croque Madam, chicken ', 'Steak, salmon, chicken parm',
#         'Spaghetti, Grilled Chicken, Pizza ',
#         'Grilled chicken, Spaghetti, Alfredo ', 'Dinner, Lunch, Dessert ',
#         'Beef Stroganoff, Chicken and Mashed Potatoes, Tacos ',
#         'Meat, meat and meat', 'Pasta, Chicken, Pizza',
#         'Rice and Peas and Chicken, Jerk Chicken and Shrimp',
#         'Vietnamese fried rolls, Pho, Some kinds of noodles.',
#         'Chinese tacos or pasta ', 'Chicken, Rice, Vegetables',
#         'pasta, fish, steak',
#         'Fried Rice \rBaked potatoes \rCurry Chicken',
#         'meat, rice, kimchi', 'Pizza, Spaghetti, Baked Ziti',
#         'Vegetables, Meat, and rice.'], dtype=object),
#  'mother_education': array([ 1.,  4.,  2.,  5.,  3., nan]),
#  'mother_profession': array(['unemployed', 'Nurse RN ', 'owns business',
#         'Special Education Teacher', 'Substance Abuse Conselor',
#         'Hair Braider', 'Journalist', 'cook', 'Elementary School Teacher',
#         'Pharmaceutical rep', 'Chidos Cleaners', 'Court Reporter ',
#         'Child care provider ', 'business owner', 'Charity worker',
#         'Librarian', 'Police', 'stay at home mom', 'Daycare provider',
#         'physical therapist', 'Teacher', 'House wife', 'Underwiriter ',
#         'Beautician ', 'Unemployed', 'Medical biller',
#         'Doctors Billing Assiant ', 'Dentist ', 'Air Traffic Controller',
#         'Strategic Planning and Programs Manager', 'teacher', 'management',
#         'Lawyer', 'stylist', 'Works in retail', 'Homemaker ',
#         'Head of Human Resouces', 'Accountant', 'Marketing Analyst',
#         'Middle school teacher', 'Art teacher ', 'Account Clerical ',
#         'Caretaker', 'Secretary', 'Registered Nurse', 'telemarketer ',
#         'nurse', 'Banker', 'Office assistant', 'Stay home', 'Unemployed ',
#         'Counseling, Teaching, Geologist, Psychic', 'factory worker',
#         'Nurse', 'Sales', 'Elementary School Principal',
#         'Real Estate Agent ', 'X-ray tech', 'Respiratory Therapist',
#         'Legal assistant', 'dietitian ', 'CNA ', 'Periodontist',
#         'business', 'Project Manager ', 'school teacher', 'Homemaker',
#         'Stay-At-Home Mom', 'Social Services', 'Runs a Daycare',
#         'Customer Service', nan, 'RN', 'program director',
#         'Programs coordinator ', 'self employed', 'none',
#         'Legal Secretary', 'secretary ',
#         'works in Loans department in First National Bank', 'Janitor',
#         'Yoga Instructor ', 'Sales Manager at Business First',
#         'principal ', 'home cleaner', 'A teacher ', 'Secretary ',
#         'Customer Service Representative ', 'Stay at home mother',
#         'Treasurer', 'Special Ed Teacher', 'Accountant ',
#         'certified accountant', 'nothing ', 'social worker',
#         'Substitute Secretary', 'Insurance Coordinator', 'Supervisor',
#         'Travel Agent', 'Real Estate', 'School Library Media Specialist ',
#         'Deceased', 'Fourth Grade Teacher ',
#         'Works in WWF, world wild life fund', 'Health teacher',
#         'Business Woman', 'Her own business',
#         'Grieveance coordinator of the SCI albion prison ',
#         'Radiological Technician ', 'Public Health Advisor ',
#         'Real Estate manageer',
#         'Receptionist for a medical supply company', 'House-wife'],
#        dtype=object),
#  'nutritional_check': array([5, 4, 2, 3, 1], dtype=int64),
#  'on_off_campus': array([ 1.,  2.,  3.,  4., nan]),
#  'parents_cook': array([1, 2, 3, 5], dtype=int64),
#  'pay_meal_out': array([2, 4, 3, 5, 6], dtype=int64),
#  'persian_food': array([ 5.,  4.,  2.,  1.,  3., nan]),
#  'self_perception_weight': array([ 3.,  6.,  5.,  4.,  1.,  2., nan]),
#  'soup': array([ 1.,  2., nan]),
#  'sports': array([ 1.,  2., nan]),
#  'thai_food': array([1, 2, 5, 4, 3], dtype=int64),
#  'tortilla_calories': array([1165.,  725.,  940.,  580.,   nan]),
#  'turkey_calories': array([345, 690, 500, 850], dtype=int64),
#  'type_sports': array(['car racing', 'Basketball ', 'none', nan, 'Softball', 'None.',
#         'soccer', 'field hockey', 'Running', 'Soccer and basketball ',
#         'intramural volleyball', 'Hockey', 'hockey', 'dancing ',
#         'basketball', 'Soccer', 'Tennis', 'tennis soccer gym',
#         'Gaelic Football', 'Ice hockey', 'Lacrosse ', 'snowboarding',
#         'none organized', 'softball', 'Lacrosse', 'Softball ', 'Dancing',
#         'wrestling ', 'no particular engagement ', 'Volleyball', 'soccer ',
#         'wrestling & rowing', 'Wrestling', 'Skiing', 'skiing ',
#         'Water polo and running ', 'Ice Hockey', 'rowing ', 'tennis  ',
#         'Recreational Basketball, Equestrian Team', 'Rec Volleyball',
#         'baseball', 'I danced in high school', 'horse back riding',
#         'competitive skiing', 'Rowing, Running, and Cycling',
#         'softball and basketball', 'wrestling', 'Marching Band',
#         'Collegiate Water Polo', 'None right now', 'volleyball, lacrosse',
#         'none ', 'Fotball', 'crew',
#         'Football, Basketball, Volleyball, Golf', 'hockey, soccer, golf',
#         'Running ', 'Volleyball, Track',
#         'When I can, rarely though play pool, darts, and basketball.',
#         'None at the moment', 'volleyball', 'I used to play softball ',
#         ' None', 'Tennis, Basketball', "No, I don't play sport.",
#         'basketball '], dtype=object),
#  'veggies_day': array([5, 4, 3, 1, 2], dtype=int64),
#  'vitamins': array([1, 2], dtype=int64),
#  'waffle_calories': array([1315,  900,  760,  575], dtype=int64),
#  'weight': array(['187', '155', "I'm not answering this. ", 'Not sure, 240', '190',
#         '180', '137', '125', '116', '110', '264', '123', '185', '145',
#         '170', '135', '165', '175', '195', '105', '160', '167', '115',
#         '205', nan, '128', '150', '140', '120', '100', '113', '168', '169',
#         '200', '265', '192', '118', '210', '112', '144 lbs', '130', '127',
#         '129', '260', '184', '230', '138', '156'], dtype=object)}

# %%
for col in df.select_dtypes(include=np.number).columns:
    df[col].fillna(df[col].median(), inplace=True)

for col in df.select_dtypes(include=object).columns:
    df[col].fillna("Desconhecido", inplace=True)


def to_numeric(x):
    try:
        return pd.to_numeric(x)
    except Exception:
        return np.nan


for col in ["GPA", "weight"]:
    df[col] = (
        df[col].astype(str).str.replace(r"[^\d.]", "", regex=True).apply(to_numeric)
    )
    df[col].fillna(df[col].median(), inplace=True)

df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0  2.400       2          1               430           3.0           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2  3.300       1          1               720           4.0           420.0
# 3  3.200       1          1               430           3.0           420.0
# 4  3.500       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  cook  comfort_food_reasons_coded.1  cuisine  \
# 0                         9.0   2.0                             9      1.0
# 1                         1.0   3.0                             1      1.0
# 2                         1.0   1.0                             1      3.0
# 3                         2.0   2.0                             2      2.0
# 4                         1.0   1.0                             1      2.0
#
#                                         diet_current  diet_current_coded  \
# 0                              eat good and exercise                   1
# 1  I eat about three times a day with some snacks...                   2
# 2  toast and fruit for breakfast, salad for lunch...                   3
# 3  College diet, cheap and easy foods most nights...                   2
# 4  I try to eat healthy but often struggle becaus...                   2
#
#    drink                                     eating_changes  \
# 0    1.0                                        eat faster
# 1    2.0                        I eat out more than usual.
# 2    1.0  sometimes choosing to eat fast food instead of...
# 3    2.0     Accepting cheap and premade/store bought foods
# 4    2.0  I have eaten generally the same foods but I do...
#
#    eating_changes_coded  eating_changes_coded1  eating_out  employment  \
# 0                     1                      1           3         3.0
# 1                     1                      2           2         2.0
# 2                     1                      3           2         3.0
# 3                     1                      3           2         3.0
# 4                     3                      4           2         2.0
#
#    ethnic_food  exercise  father_education father_profession     fav_cuisine  \
# 0            1       1.0               5.0         profesor   Arabic cuisine
# 1            4       1.0               2.0    Self employed          Italian
# 2            5       2.0               2.0     owns business         italian
# 3            5       3.0               2.0         Mechanic         Turkish
# 4            4       1.0               4.0                IT        Italian
#
#    fav_cuisine_coded  fav_food                                food_childhood  \
# 0                  3       1.0                            rice  and chicken
# 1                  1       1.0  chicken and biscuits, beef soup, baked beans
# 2                  1       3.0                  mac and cheese, pizza, tacos
# 3                  3       1.0                 Beef stroganoff, tacos, pizza
# 4                  1       3.0                 Pasta, chicken tender, pizza
#
#    fries  fruit_day  grade_level  greek_food  healthy_feeling  \
# 0      2          5            2           5                2
# 1      1          4            4           4                5
# 2      1          5            3           5                6
# 3      2          4            4           5                7
# 4      1          4            4           4                6
#
#                                         healthy_meal  \
# 0                                    looks not oily
# 1  Grains, Veggies, (more of grains and veggies),...
# 2  usually includes natural ingredients; nonproce...
# 3           Fresh fruits& vegetables, organic meats
# 4  A lean protein such as grilled chicken, green ...
#
#                                           ideal_diet  ideal_diet_coded  \
# 0                                     being healthy                  8
# 1  Try to eat 5-6 small meals a day. While trying...                 3
# 2       i would say my ideal diet is my current diet                 6
# 3     Healthy, fresh veggies/fruits & organic foods                  2
# 4  Ideally I would like to be able to eat healthi...                 2
#
#    income  indian_food  italian_food  life_rewarding  marital_status  \
# 0     5.0            5             5             1.0             1.0
# 1     4.0            4             4             1.0             2.0
# 2     6.0            5             5             7.0             2.0
# 3     6.0            5             5             2.0             2.0
# 4     6.0            2             5             1.0             1.0
#
#                                  meals_dinner_friend  mother_education  \
# 0                               rice, chicken,  soup               1.0
# 1                             Pasta, steak, chicken                4.0
# 2  chicken and rice with veggies, pasta, some kin...               2.0
# 3   Grilled chicken \rStuffed Shells\rHomemade Chili               4.0
# 4  Chicken Parmesan, Pulled Pork, Spaghetti and m...               5.0
#
#            mother_profession  nutritional_check  on_off_campus  parents_cook  \
# 0                 unemployed                  5            1.0             1
# 1                  Nurse RN                   4            1.0             1
# 2              owns business                  4            2.0             1
# 3  Special Education Teacher                  2            1.0             1
# 4   Substance Abuse Conselor                  3            1.0             1
#
#    pay_meal_out  persian_food  self_perception_weight  soup  sports  \
# 0             2           5.0                     3.0   1.0     1.0
# 1             4           4.0                     3.0   1.0     1.0
# 2             3           5.0                     6.0   1.0     2.0
# 3             2           5.0                     5.0   1.0     2.0
# 4             4           2.0                     4.0   1.0     1.0
#
#    thai_food  tortilla_calories  turkey_calories   type_sports  veggies_day  \
# 0          1             1165.0              345    car racing            5
# 1          2              725.0              690   Basketball             4
# 2          5             1165.0              500          none            5
# 3          5              725.0              690  Desconhecido            3
# 4          4              940.0              500      Softball            4
#
#    vitamins  waffle_calories  weight
# 0         1             1315   187.0
# 1         2              900   155.0
# 2         1              900   155.0
# 3         1             1315   240.0
# 4         2              760   190.0

# %%
# df["Gender"] = df["Gender"].apply(lambda x: "male" if x != 1 else "female")
# df["breakfast"] = df["breakfast"].apply(lambda x: "good" if x == 1 else "bad")
df.drop(columns=["calories_chicken", "calories_day", "calories_scone"], inplace=True)
# df["coffee"] = df["coffee"].apply(lambda x: "good" if x != 1 else "bad")
df.head()
# Out:
#      GPA  Gender  breakfast  coffee                      comfort_food  \
# 0  2.400       2          1       1                              none
# 1  3.654       1          1       2       chocolate, chips, ice cream
# 2  3.300       1          1       2   frozen yogurt, pizza, fast food
# 3  3.200       1          1       2  Pizza, Mac and cheese, ice cream
# 4  3.500       1          1       2      Ice cream, chocolate, chips
#
#          comfort_food_reasons  comfort_food_reasons_coded  cook  \
# 0       we dont have comfort                          9.0   2.0
# 1        Stress, bored, anger                         1.0   3.0
# 2             stress, sadness                         1.0   1.0
# 3                     Boredom                         2.0   2.0
# 4  Stress, boredom, cravings                          1.0   1.0
#
#    comfort_food_reasons_coded.1  cuisine  \
# 0                             9      1.0
# 1                             1      1.0
# 2                             1      3.0
# 3                             2      2.0
# 4                             1      2.0
#
#                                         diet_current  diet_current_coded  \
# 0                              eat good and exercise                   1
# 1  I eat about three times a day with some snacks...                   2
# 2  toast and fruit for breakfast, salad for lunch...                   3
# 3  College diet, cheap and easy foods most nights...                   2
# 4  I try to eat healthy but often struggle becaus...                   2
#
#    drink                                     eating_changes  \
# 0    1.0                                        eat faster
# 1    2.0                        I eat out more than usual.
# 2    1.0  sometimes choosing to eat fast food instead of...
# 3    2.0     Accepting cheap and premade/store bought foods
# 4    2.0  I have eaten generally the same foods but I do...
#
#    eating_changes_coded  eating_changes_coded1  eating_out  employment  \
# 0                     1                      1           3         3.0
# 1                     1                      2           2         2.0
# 2                     1                      3           2         3.0
# 3                     1                      3           2         3.0
# 4                     3                      4           2         2.0
#
#    ethnic_food  exercise  father_education father_profession     fav_cuisine  \
# 0            1       1.0               5.0         profesor   Arabic cuisine
# 1            4       1.0               2.0    Self employed          Italian
# 2            5       2.0               2.0     owns business         italian
# 3            5       3.0               2.0         Mechanic         Turkish
# 4            4       1.0               4.0                IT        Italian
#
#    fav_cuisine_coded  fav_food                                food_childhood  \
# 0                  3       1.0                            rice  and chicken
# 1                  1       1.0  chicken and biscuits, beef soup, baked beans
# 2                  1       3.0                  mac and cheese, pizza, tacos
# 3                  3       1.0                 Beef stroganoff, tacos, pizza
# 4                  1       3.0                 Pasta, chicken tender, pizza
#
#    fries  fruit_day  grade_level  greek_food  healthy_feeling  \
# 0      2          5            2           5                2
# 1      1          4            4           4                5
# 2      1          5            3           5                6
# 3      2          4            4           5                7
# 4      1          4            4           4                6
#
#                                         healthy_meal  \
# 0                                    looks not oily
# 1  Grains, Veggies, (more of grains and veggies),...
# 2  usually includes natural ingredients; nonproce...
# 3           Fresh fruits& vegetables, organic meats
# 4  A lean protein such as grilled chicken, green ...
#
#                                           ideal_diet  ideal_diet_coded  \
# 0                                     being healthy                  8
# 1  Try to eat 5-6 small meals a day. While trying...                 3
# 2       i would say my ideal diet is my current diet                 6
# 3     Healthy, fresh veggies/fruits & organic foods                  2
# 4  Ideally I would like to be able to eat healthi...                 2
#
#    income  indian_food  italian_food  life_rewarding  marital_status  \
# 0     5.0            5             5             1.0             1.0
# 1     4.0            4             4             1.0             2.0
# 2     6.0            5             5             7.0             2.0
# 3     6.0            5             5             2.0             2.0
# 4     6.0            2             5             1.0             1.0
#
#                                  meals_dinner_friend  mother_education  \
# 0                               rice, chicken,  soup               1.0
# 1                             Pasta, steak, chicken                4.0
# 2  chicken and rice with veggies, pasta, some kin...               2.0
# 3   Grilled chicken \rStuffed Shells\rHomemade Chili               4.0
# 4  Chicken Parmesan, Pulled Pork, Spaghetti and m...               5.0
#
#            mother_profession  nutritional_check  on_off_campus  parents_cook  \
# 0                 unemployed                  5            1.0             1
# 1                  Nurse RN                   4            1.0             1
# 2              owns business                  4            2.0             1
# 3  Special Education Teacher                  2            1.0             1
# 4   Substance Abuse Conselor                  3            1.0             1
#
#    pay_meal_out  persian_food  self_perception_weight  soup  sports  \
# 0             2           5.0                     3.0   1.0     1.0
# 1             4           4.0                     3.0   1.0     1.0
# 2             3           5.0                     6.0   1.0     2.0
# 3             2           5.0                     5.0   1.0     2.0
# 4             4           2.0                     4.0   1.0     1.0
#
#    thai_food  tortilla_calories  turkey_calories   type_sports  veggies_day  \
# 0          1             1165.0              345    car racing            5
# 1          2              725.0              690   Basketball             4
# 2          5             1165.0              500          none            5
# 3          5              725.0              690  Desconhecido            3
# 4          4              940.0              500      Softball            4
#
#    vitamins  waffle_calories  weight
# 0         1             1315   187.0
# 1         2              900   155.0
# 2         1              900   155.0
# 3         1             1315   240.0
# 4         2              760   190.0

# %%
util = df[
    [
        "GPA",
        "Gender",
        "grade_level",
        "employment",
        "eating_out",
        "nutritional_check",
        "on_off_campus",
        # "exercice",
        "breakfast",
        "coffee",
        "self_perception_weight",
        "type_sports",
        "sports",
        "weight",
    ]
].copy()
util.loc[:, "self_perception_overweight"] = util["self_perception_weight"].apply(
    lambda x: True if x > 3 else False
)
util.drop(columns=["self_perception_weight"], inplace=True)
util.to_csv("../data/interim/filtered.csv", index=False)
# 4. Remoção de caracteres irregulares:
util.head()
# Out:
#      GPA  Gender  grade_level  employment  eating_out  nutritional_check  \
# 0  2.400       2            2         3.0           3                  5
# 1  3.654       1            4         2.0           2                  4
# 2  3.300       1            3         3.0           2                  4
# 3  3.200       1            4         3.0           2                  2
# 4  3.500       1            4         2.0           2                  3
#
#    on_off_campus  breakfast  coffee   type_sports  sports  weight  \
# 0            1.0          1       1    car racing     1.0   187.0
# 1            1.0          1       2   Basketball      1.0   155.0
# 2            2.0          1       2          none     2.0   155.0
# 3            1.0          1       2  Desconhecido     2.0   240.0
# 4            1.0          1       2      Softball     1.0   190.0
#
#    self_perception_overweight
# 0                       False
# 1                       False
# 2                        True
# 3                        True
# 4                        True

# %%
fisicos = [
    "basketball",
    "softball",
    "soccer",
    "field hockey",
    "running",
    "hockey",
    "dancing",
    "volleyball",
    "gym",
]
util["type_sports"] = util["type_sports"].apply(
    lambda x: 1 if x.lower() in fisicos else 0
)

# %% [markdown]
# ### Divisão do conjunto de dados

# %%
X_train, X_test, y_train, y_test = train_test_split(
    util.drop(columns=["self_perception_overweight"]),
    util["self_perception_overweight"],
    test_size=0.2,
    random_state=42,
)
# X_train["target"] = y_train
# X_test["target"] = y_test
# X_train.to_csv("../data/processed/train.csv", index=False)
# X_test.to_csv("../data/processed/test.csv", index=False)

# %% [markdown]
# ### Avaliação dos modelos

# %%
def create_models():
    gnb = GaussianNB()
    knn = KNeighborsClassifier(n_neighbors=5)
    svm_linear = make_pipeline(StandardScaler(), SVC(kernel="linear", probability=True))
    svm_rbf = make_pipeline(StandardScaler(), SVC(kernel="rbf", probability=True))
    dt = DecisionTreeClassifier(random_state=42)
    rf = RandomForestClassifier(n_estimators=100, random_state=42)
    mlp = make_pipeline(
        StandardScaler(),
        MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, random_state=42),
    )
    return gnb, knn, svm_linear, svm_rbf, dt, rf, mlp

# %%
gnb, knn, svm_linear, svm_rbf, dt, rf, mlp = create_models()

models = [
    ("Naive Bayes", gnb),
    ("k-NN", knn),
    ("SVM Linear", svm_linear),
    ("SVM RBF", svm_rbf),
    ("Decision Tree", dt),
    ("Random Forest", rf),
    ("MLP", mlp),
]

# Avaliar cada modelo
for name, model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"Modelo: {name}")
    print(f"Acurácia: {accuracy_score(y_test, y_pred):.2f}")
    print(f"Precisão: {precision_score(y_test, y_pred):.2f}")
    print(f"Recall: {recall_score(y_test, y_pred):.2f}")
    print(f"F1-score: {f1_score(y_test, y_pred):.2f}")
    print("=" * 30)
# Out:
# Modelo: Naive Bayes
# Acurácia: 0.72
# Precisão: 0.67
# Recall: 0.44
# F1-score: 0.53
# ==============================
# Modelo: k-NN
# Acurácia: 0.72
# Precisão: 1.00
# Recall: 0.22
# F1-score: 0.36
# ==============================
# Modelo: SVM Linear
# Acurácia: 0.76
# Precisão: 0.80
# Recall: 0.44
# F1-score: 0.57
# ==============================
# Modelo: SVM RBF
# Acurácia: 0.68
# Precisão: 0.67
# Recall: 0.22
# F1-score: 0.33
# ==============================
# Modelo: Decision Tree
# Acurácia: 0.48
# Precisão: 0.33
# Recall: 0.44
# F1-score: 0.38
# ==============================
# Modelo: Random Forest
# Acurácia: 0.64
# Precisão: 0.50
# Recall: 0.22
# F1-score: 0.31
# ==============================
# Modelo: MLP
# Acurácia: 0.52
# Precisão: 0.38
# Recall: 0.56
# F1-score: 0.45
# ==============================

# %%
for name, model in models:
    scores = cross_val_score(model, X_test, y_test, cv=5, scoring="accuracy")
    print(f"Modelo: {name}")
    print(f"Acurácia média (Val. Cruzada): {scores.mean():.2f}")
    print("=" * 30)
# Out:
# Modelo: Naive Bayes
# Acurácia média (Val. Cruzada): 0.48
# ==============================
# Modelo: k-NN
# Acurácia média (Val. Cruzada): 0.64
# ==============================
# Modelo: SVM Linear
# Acurácia média (Val. Cruzada): 0.60
# ==============================
# Modelo: SVM RBF
# Acurácia média (Val. Cruzada): 0.56
# ==============================
# Modelo: Decision Tree
# Acurácia média (Val. Cruzada): 0.48
# ==============================
# Modelo: Random Forest
# Acurácia média (Val. Cruzada): 0.52
# ==============================
# Modelo: MLP
# Acurácia média (Val. Cruzada): 0.56
# ==============================

# %%
grid_search_rf = GridSearchCV(
    RandomForestClassifier(random_state=42),
    {
        "n_estimators": [50, 100, 200],
        "max_depth": [None, 10, 20],
        "min_samples_split": [2, 5, 10],
    },
    cv=5,
    scoring="accuracy",
).fit(X_train, y_train)

print("Melhores hiperparâmetros para Random Forest:")
print(grid_search_rf.best_params_)
print(f"Melhor acurácia (Val. Cruzada): {grid_search_rf.best_score_:.2f}")
# Out:
# Melhores hiperparâmetros para Random Forest:
# {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 200}
# Melhor acurácia (Val. Cruzada): 0.72

# %%
grid_search_svm = GridSearchCV(
    svm_rbf,
    {
        "svc__C": [0.1, 1, 10],
        "svc__gamma": ["scale", 0.1, 1],
        "svc__kernel": ["rbf", "linear"],
    },
    cv=5,
    scoring="accuracy",
).fit(X_train, y_train)

print("Melhores hiperparâmetros para SVM:")
print(grid_search_svm.best_params_)
print(f"Melhor acurácia (Val. Cruzada): {grid_search_svm.best_score_:.2f}")
# Out:
# Melhores hiperparâmetros para SVM:
# {'svc__C': 1, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# Melhor acurácia (Val. Cruzada): 0.75

# %% [markdown]
# ### Treinamento e avaliação

# %%
gnb, knn, svm_linear, svm_rbf, dt, rf, mlp = create_models()

voting_clf = VotingClassifier(
    estimators=[
        ("gnb", gnb),
        ("knn", knn),
        ("svm_linear", svm_linear),
        ("svm_rbf", svm_rbf),
        ("dt", dt),
        ("rf", rf),
        ("mlp", mlp),
    ],
    voting="soft",
).fit(X_train, y_train)

print(f"Acurácia: {accuracy_score(y_test, voting_clf.predict(X_test)):.2f}")
# Out:
# Acurácia: 0.68

# %% [markdown]
# ### Análise dos resultados
